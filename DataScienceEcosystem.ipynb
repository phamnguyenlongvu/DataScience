# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summerized.

# %% [markdown]
# __Objectives:__
# - List popular languages for Data Science
# - List common libraries for Data Science
# - List tools for Data Science
# - Arithmetic expression in Jupyter Notebook.

# %% [markdown]
# Some of popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. ggplot
# 3. matplotlib
# 4. numpy

# %% [markdown]
# |Data Science Tools|
# --------------------
# |Python|
# |R|
# |SQL|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to mutiply the add integers
(3*4)+5
# Out:
# 17

# %%
# This will cover 200 minutes to hours by diving by 60
200/60.
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author: Pham Nguyen Lon Vu
